# %% [markdown]
# # Importing packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
nrows = 100

# %% [markdown]
# # Input Retail data analysis

# %%
nrows = int(1e3)

retail_snapshos_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Retail\retail_inventory_snapshot_30_10_25.csv", nrows=nrows)
retail_sales_df= pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Retail\retail_sales_data_01_09_2023_to_31_10_2025.csv", nrows=nrows)

print(f"retail snapshot info:\n")
print(retail_snapshos_df.info())
print("\n\n")
print("retail sales info:")
print(retail_sales_df.info())
# Out:
# retail snapshot info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Product             1000 non-null   object
#  1   Packsize            835 non-null    object
#  2   Headoffice ID       1000 non-null   int64
#  3   Barcode             981 non-null    float64
#  4   Barcode2            0 non-null      float64
#  5   Barcode3            0 non-null      float64
#  6   OrderList           461 non-null    object
#  7   Case Size           1000 non-null   int64
#  8   Trade Price         1000 non-null   float64
#  9   RRP                 1000 non-null   float64
#  10  Dept Fullname       999 non-null    object
#  11  Group Fullname      999 non-null    object
#  12  Branch Name         999 non-null    object
#  13  Branch Stock Level  999 non-null    float64
# dtypes: float64(6), int64(2), object(6)
# ...

# %%
retail_snapshos_df.iloc[0]
# Out:
# Product                Baby Poem Photo Plaque
# Packsize                                17X32
# Headoffice ID                           58354
# Barcode                       5024420000000.0
# Barcode2                                  NaN
# Barcode3                                  NaN
# OrderList                               Sifco
# Case Size                                   6
# Trade Price                              3.15
# RRP                                       7.5
# Dept Fullname              Gifts : Baby Gifts
# Group Fullname                          Gifts
# Branch Name                         Baggot St
# Branch Stock Level                        0.0
# Name: 0, dtype: object

# %% [markdown]
# # Input online data

# %%
intentory_tags_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\inventory_tags.csv", nrows=nrows)
order_fufillments_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\order_fulfillments.csv", nrows=nrows)
order_line_items_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\order_line_items.csv", nrows=nrows)


print(f"invnetory tags info:\n")
print(intentory_tags_df.info())
print("\n\n")
print("order fufillments info:")
print(order_fufillments_df.info())
print("\n\n")
print("order line items info:")
print(order_line_items_df.info())
# Out:
# invnetory tags info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   inventory_product_id  1000 non-null   object
#  1   inventory_tag         1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB
# None
#
#
#
# order fufillments info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1000 non-null   object
#  1   fulfillment_data  1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB
# None
#
#
#
# order line items info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ...

# %%
orders_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\orders.csv", nrows=nrows)
order_line_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\order_line_items.csv", nrows=nrows)

# %%
print(orders_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 55 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   order_id                              100 non-null    object
#  1   legacyResourceId                      100 non-null    int64
#  2   order_name                            100 non-null    object
#  3   email                                 100 non-null    object
#  4   phone                                 100 non-null    object
#  5   createdAt                             100 non-null    object
#  6   updatedAt                             100 non-null    object
#  7   processedAt                           100 non-null    object
#  8   closedAt                              100 non-null    object
#  9   cancelledAt                           0 non-null      float64
#  10  currencyCode                          100 non-null    object
# ...

# %%
orders_df.iloc[0]
# number of rows (so number of orders): 1145858
# Out:
# order_id                                   gid://shopify/Order/4866314403953
# legacyResourceId                                               4866314403953
# order_name                                                           #567151
# email                                                     user998@anon_ok.me
# phone                                                             [REDACTED]
# createdAt                                                2023-02-07 12:02:49
# updatedAt                                                2023-03-30 12:30:45
# processedAt                                              2023-02-07 12:02:44
# closedAt                                                 2023-02-08 08:39:30
# cancelledAt                                                              NaN
# currencyCode                                                             EUR
# presentmentCurrencyCode                                                  EUR
# ...

# %%
order_line_df.info()
order_line_df.iloc[0]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               100 non-null    object
#  1   line_item_id           100 non-null    object
#  2   product_id             89 non-null     object
#  3   variant_id             77 non-null     object
#  4   title                  100 non-null    object
#  5   name                   100 non-null    object
#  6   sku                    100 non-null    int64
#  7   variant_title          36 non-null     object
#  8   vendor                 100 non-null    object
#  9   quantity               100 non-null    int64
#  10  original_unit_price    100 non-null    float64
#  11  discounted_unit_price  100 non-null    float64
#  12  discounted_total       100 non-null    float64
#  13  currency               100 non-null    object
# ...

# %%
orders_df.iloc[0]
# Out:
# order_id                                   gid://shopify/Order/4866314403953
# legacyResourceId                                               4866314403953
# order_name                                                           #567151
# email                                                     user998@anon_ok.me
# phone                                                             [REDACTED]
# createdAt                                                2023-02-07 12:02:49
# updatedAt                                                2023-03-30 12:30:45
# processedAt                                              2023-02-07 12:02:44
# closedAt                                                 2023-02-08 08:39:30
# cancelledAt                                                              NaN
# currencyCode                                                             EUR
# presentmentCurrencyCode                                                  EUR
# ...

# %%
order_line_df.head()
# Out:
#                             order_id                           line_item_id  \
# 0  gid://shopify/Order/5699898048856  gid://shopify/LineItem/14812772925784
# 1  gid://shopify/Order/5699912434008  gid://shopify/LineItem/14812801597784
# 2  gid://shopify/Order/5699916923224  gid://shopify/LineItem/14812812968280
# 3  gid://shopify/Order/5700026794328  gid://shopify/LineItem/14813201924440
# 4  gid://shopify/Order/5700050157912  gid://shopify/LineItem/14813284172120
#
#                             product_id  \
# 0  gid://shopify/Product/4671125749873
# 1  gid://shopify/Product/6662534725745
# 2  gid://shopify/Product/4637992091761
# 3  gid://shopify/Product/4545826750577
# 4  gid://shopify/Product/6812022243441
#
#                                     variant_id  \
# 0  gid://shopify/ProductVariant/32322892267633
# 1  gid://shopify/ProductVariant/39613368565873
# 2  gid://shopify/ProductVariant/32261439717489
# 3  gid://shopify/ProductVariant/31935235489905
# ...

# %%
pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\order_fulfillments.csv", nrows=nrows).head()
# Out:
#                             order_id  \
# 0  gid://shopify/Order/3086563377265
# 1  gid://shopify/Order/3086673608817
# 2  gid://shopify/Order/3087212413041
# 3  gid://shopify/Order/3087213789297
# 4  gid://shopify/Order/3087213887601
#
#                                     fulfillment_data
# 0  {'id': 'gid://shopify/Fulfillment/290861275556...
# 1  {'id': 'gid://shopify/Fulfillment/291470671883...
# 2  {'id': 'gid://shopify/Fulfillment/290922423921...
# 3  {'id': 'gid://shopify/Fulfillment/290922433752...
# 4  {'id': 'gid://shopify/Fulfillment/290922437028...

# %% [markdown]
# # Output data

# %%
daily_sales_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\output_data\Daily_Sales_Report.csv", nrows=nrows)
weekly_sales_df =  pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\output_data\Weekly_Sales_Dashboard.csv", nrows=nrows)
product_performance_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\output_data\Product_Performance_Report_Example.csv", nrows=nrows)


print(f"daily sales info:\n")
print(daily_sales_df.info())
print("\n\n")
print("weekly sales info:")
print(weekly_sales_df.info())
print("\n\n")
print("product performance info:")
print(product_performance_df.info())
# Out:
# daily sales info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 12 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   DAILY SALES REPORT - MANUAL HUMAN REPORT  18 non-null     object
#  1   Unnamed: 1                                3 non-null      object
#  2   Unnamed: 2                                3 non-null      object
#  3   Unnamed: 3                                3 non-null      object
#  4   Unnamed: 4                                3 non-null      object
#  5   Unnamed: 5                                3 non-null      object
#  6   Unnamed: 6                                1 non-null      object
#  7   Unnamed: 7                                3 non-null      object
#  8   Unnamed: 8                                1 non-null      object
#  9   Unnamed: 9                                1 non-null      object
# ...
