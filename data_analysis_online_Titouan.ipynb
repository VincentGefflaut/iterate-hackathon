# %% [markdown]
# # Import packages

# %%
import pandas as pd
nrows = 100

# %% [markdown]
# # Non-orders datasets

# %%
products_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\products.csv")
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22744 entries, 0 to 22743
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     22743 non-null  object
#  1   legacyResourceId       8727 non-null   float64
#  2   handle                 4925 non-null   object
#  3   title                  9755 non-null   object
#  4   vendor                 3897 non-null   object
#  5   productType            3850 non-null   object
#  6   status                 3897 non-null   object
#  7   createdAt              8727 non-null   object
#  8   updatedAt              8727 non-null   object
#  9   publishedAt            3644 non-null   object
#  10  templateSuffix         31 non-null     object
#  11  totalInventory         3897 non-null   float64
#  12  tracksInventory        3897 non-null   object
#  13  onlineStoreUrl         3644 non-null   object
# ...

# %%
products_df.loc[~products_df.isna().any(axis=1),:].iloc[0]
# Out:
# id                                     gid://shopify/Product/4468254933105
# legacyResourceId                                           4468254933105.0
# handle                                 colpermin-gastro-resistant-caps-20s
# title                          Colpermin Gastro-Resistant Capsules 20 Pack
# vendor                                                           Colpermin
# productType                                                     Ibs Relief
# status                                                              ACTIVE
# createdAt                                              2020-05-06 13:08:03
# updatedAt                                              2025-11-11 10:17:32
# publishedAt                                            2020-05-06 11:54:39
# templateSuffix                                                   colpermin
# totalInventory                                                         7.0
# ...

# %%
orders_tags_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\order_tags.csv")
orders_tags_df.head()
# Out:
#                             order_id  tag
# 0  gid://shopify/Order/4150942990449   ah
# 1  gid://shopify/Order/4150990405745   cs
# 2  gid://shopify/Order/4151007412337  .lk
# 3  gid://shopify/Order/4151061610609    0
# 4  gid://shopify/Order/4151100375153    0

# %%
tags_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\tags.csv")
#tags_df.info()
tags_df.head()
# Out:
#                             product_id                     tag
# 0  gid://shopify/Product/4427646959729            cruelty free
# 1  gid://shopify/Product/4427646959729  vitamins & supplements
# 2  gid://shopify/Product/4427758895217                   mylan
# 3  gid://shopify/Product/4428178620529                backache
# 4  gid://shopify/Product/4428178620529             period pain

# %%
inventory_tags_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\inventory_tags.csv")
inventory_tags_df.head()
# Out:
#                   inventory_product_id inventory_tag
# 0  gid://shopify/Product/1607622000753   bath & body
# 1  gid://shopify/Product/1607622000753       batiste
# 2  gid://shopify/Product/1607622000753          BF25
# 3  gid://shopify/Product/1607622000753  Black Friday
# 4  gid://shopify/Product/1607622000753   dry-shampoo

# %%
inventory_levels_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\inventory_levels.csv")
inventory_levels_df.head()
# Out:
#                                   inventory_level_id  \
# 0  gid://shopify/InventoryLevel/15667101809?inven...
# 1  gid://shopify/InventoryLevel/95287804017?inven...
# 2  gid://shopify/InventoryLevel/15667101809?inven...
# 3  gid://shopify/InventoryLevel/95287804017?inven...
# 4  gid://shopify/InventoryLevel/15667101809?inven...
#
#                                     variant_id            createdAt  \
# 0  gid://shopify/ProductVariant/14940646473841  2018-09-28 12:37:16
# 1  gid://shopify/ProductVariant/14940646473841  2022-08-18 15:25:21
# 2  gid://shopify/ProductVariant/47868657467736  2024-02-28 09:13:03
# 3  gid://shopify/ProductVariant/47868657467736  2024-02-28 09:13:03
# 4  gid://shopify/ProductVariant/47868657500504  2024-02-28 09:13:03
#
#              updatedAt  canDeactivate                         location_id  \
# 0  2025-11-12 23:05:45          False  gid://shopify/Location/16056615025
# 1  2022-08-18 15:25:21           True  gid://shopify/Location/60970827889
# ...

# %%
inventory_products_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\inventory_products.csv")
inventory_products_df.head()
# Out:
#                           inventory_id  inventory_legacyResourceId  \
# 0  gid://shopify/Product/1607622000753               1607622000753
# 1  gid://shopify/Product/1607622623345               1607622623345
# 2  gid://shopify/Product/1607633862769               1607633862769
# 3  gid://shopify/Product/1607636090993               1607636090993
# 4  gid://shopify/Product/1607639138417               1607639138417
#
#                           inventory_handle  \
# 0         batiste-dry-shampoo-light-blonde
# 1             batiste-dry-shampoo-tropical
# 2  st-tropez-self-tan-dark-bronzing-mousse
# 3      vita-liberata-phenomenal-tan-medium
# 4    trilogy-certified-organic-rosehip-oil
#
#                                  inventory_title inventory_vendor  \
# 0             Batiste Dry Shampoo Light & Blonde          Batiste
# 1                   Batiste Dry Shampoo Tropical          Batiste
# 2  St.Tropez Self Tan Dark Bronzing Mousse 200ml        St.Tropez
# ...

# %%
inventory_variants_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\inventory_variants.csv")
inventory_variants_df.head()
# Out:
#                           inventory_variant_id  \
# 0  gid://shopify/ProductVariant/14940646473841
# 1  gid://shopify/ProductVariant/47868657467736
# 2  gid://shopify/ProductVariant/47868657500504
# 3  gid://shopify/ProductVariant/14940832497777
# 4  gid://shopify/ProductVariant/39799891558513
#
#                   inventory_product_id inventory_sku  \
# 0  gid://shopify/Product/1607622000753         45658
# 1  gid://shopify/Product/1607622623345         34190
# 2  gid://shopify/Product/1607622623345         96564
# 3  gid://shopify/Product/1607633862769         74395
# 4  gid://shopify/Product/1607636090993         92478
#
#   inventory_variant_createdAt inventory_variant_updatedAt
# 0         2018-09-28 12:37:16         2025-11-12 23:05:45
# 1         2024-02-28 09:13:02         2025-11-06 08:02:42
# 2         2024-02-28 09:13:03         2025-11-08 11:07:36
# 3         2018-09-28 12:39:10         2025-07-20 23:00:13
# 4         2022-06-02 09:48:24         2025-10-18 10:26:41

# %% [markdown]
# # orderes datasets

# %%
orders = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\orders.csv", nrows=nrows)
orders.iloc[0]
# Out:
# order_id                                   gid://shopify/Order/4866314403953
# legacyResourceId                                               4866314403953
# order_name                                                           #567151
# email                                                     user998@anon_ok.me
# phone                                                             [REDACTED]
# createdAt                                                2023-02-07 12:02:49
# updatedAt                                                2023-03-30 12:30:45
# processedAt                                              2023-02-07 12:02:44
# closedAt                                                 2023-02-08 08:39:30
# cancelledAt                                                              NaN
# currencyCode                                                             EUR
# presentmentCurrencyCode                                                  EUR
# ...

# %%
order_line_items_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\order_line_items.csv", nrows=nrows)
order_line_items_df.iloc[4]
# Out:
# order_id                           gid://shopify/Order/5700050157912
# line_item_id                   gid://shopify/LineItem/14813284172120
# product_id                       gid://shopify/Product/6812022243441
# variant_id               gid://shopify/ProductVariant/40051095634033
# title                              fabÜ SHROOMS Meno & Peri Capsules
# name                                                      [REDACTED]
# sku                                                            94392
# variant_title                                                    NaN
# vendor                                                          fabÜ
# quantity                                                           1
# original_unit_price                                            28.95
# discounted_unit_price                                          28.95
# discounted_total                                               28.95
# currency                                                         EUR
# ...

# %%
df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\order_fulfillments.csv", nrows=nrows)
df.loc[0,"fulfillment_data"]
# Out:
# "{'id': 'gid://shopify/Fulfillment/2908612755569', 'status': 'SUCCESS', 'displayStatus': 'CONFIRMED', 'totalQuantity': 1, 'createdAt': datetime.datetime(2021, 2, 1, 22, 25, 15), 'updatedAt': datetime.datetime(2021, 2, 4, 18, 55, 46), 'trackingInfo': array([{'number': '851491333', 'url': 'https://dpd.ie/tracking?consignmentNumber=851491333', 'company': 'DPD Ireland'}],\n      dtype=object)}"

# %% [markdown]
# # Selecting the right feature/dataset

# %%
products_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\products.csv")
products_df.head()
# Out:
#                                       id  legacyResourceId  \
# 0  gid://shopify/Collection/102276431985               NaN
# 1  gid://shopify/Collection/102942965873               NaN
# 2  gid://shopify/Collection/156453077105               NaN
# 3  gid://shopify/Collection/156453535857               NaN
# 4  gid://shopify/Collection/156897476721               NaN
#
#                              handle                             title vendor  \
# 0                    eye-ear-health                  Eye & Ear Health    NaN
# 1       la-roche-posay-kids-suncare       La Roche-Posay Kids Suncare    NaN
# 2                    vegan-skincare                    Vegan Skincare    NaN
# 3        vegan-vitamins-supplements      Vegan Vitamins & Supplements    NaN
# 4  2020-all-collections-except-sale  2020 All Collections Except Sale    NaN
#
#   productType status createdAt updatedAt publishedAt  ... descriptionHtml  \
# ...

# %%
products_df[["category_id", "category_name", "category_full_name"]].nunique()
# Out:
# category_id           244
# category_name         244
# category_full_name    244
# dtype: int64

# %%
tags_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\tags.csv")
tags_df["tag"].nunique()
# Out:
# 2053

# %%
inventory_tags_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\inventory_tags.csv")
inventory_tags_df["inventory_tag"].nunique()
# Out:
# 2049

# %%
inventory_products_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\inventory_products.csv")
inventory_products_df["inventory_productType"].nunique()
inventory_products_df["inventory_productType"].unique()
# Out:
# array(['Dry Shampoo', 'Tanning Mousse', 'Face Oil',
#        'Vitamins & Supplements', 'Cleanser', 'Serum', 'Facial Peel',
#        'Body Exfoliator', 'Neck Cream', 'Hair Treatment',
#        'Body Moisturiser', 'Face Moisturisers', 'Shower Gel',
#        'Sun Protection', 'Micellar Water', 'Day Cream', 'Eye Serum',
#        'Sleep Aid', 'Shampoo', 'Skincare Set', 'Lotion', 'Cream',
#        'Cleansing Gel', 'Soap', 'Cleansing Mitt', 'Bath Soak',
#        'Thermal Water', 'Multi-Purpose Balm', 'Lip Balm', 'Toner',
#        'Night Cream', 'Hand Cream', 'Skin Treatment', 'Eye Cream',
#        'Tanning Mitt', 'Makeup Brush', 'Deodorant', 'Shaving Gel',
#        'Eye Treatment', 'Shower Oil', "Children's Wash",
#        'Bath & Shower Gel', 'Face Cloth', 'Tanning Lotion', 'Night Oil',
#        'Eyebrow Pencil', 'Mascara', 'Face Mask', 'Makeup Brush Cleaner',
#        'Tanning Spray', 'Tanning Oil', 'Teeth Whitening Pen',
# ...

# %% [markdown]
# # Merging everything

# %%
orders = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\orders.csv")
orders.iloc[0]
# Out:
# C:\Users\titou\AppData\Local\Temp\ipykernel_15572\1259661248.py:1: DtypeWarning: Columns (35,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   orders = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\orders.csv")
# order_id                                   gid://shopify/Order/4866314403953
# legacyResourceId                                               4866314403953
# order_name                                                           #567151
# email                                                     user998@anon_ok.me
# phone                                                             [REDACTED]
# createdAt                                                2023-02-07 12:02:49
# updatedAt                                                2023-03-30 12:30:45
# processedAt                                              2023-02-07 12:02:44
# closedAt                                                 2023-02-08 08:39:30
# ...

# %%
order_line_items_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\order_line_items.csv")
order_line_items_df.iloc[4]
# Out:
# order_id                           gid://shopify/Order/5700050157912
# line_item_id                   gid://shopify/LineItem/14813284172120
# product_id                       gid://shopify/Product/6812022243441
# variant_id               gid://shopify/ProductVariant/40051095634033
# title                              fabÜ SHROOMS Meno & Peri Capsules
# name                                                      [REDACTED]
# sku                                                            94392
# variant_title                                                    NaN
# vendor                                                          fabÜ
# quantity                                                           1
# original_unit_price                                            28.95
# discounted_unit_price                                          28.95
# discounted_total                                               28.95
# currency                                                         EUR
# ...

# %%
inventory_products_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\inventory_products.csv")
inventory_products_df["inventory_productType"].nunique()

# %%
orders[["order_id","shipping_country", "shipping_province"]]
# Out:
#                                   order_id shipping_country shipping_province
# 0        gid://shopify/Order/4866314403953          Ireland          Kilkenny
# 1        gid://shopify/Order/4866315419761          Ireland             Sligo
# 2        gid://shopify/Order/4866317025393          Ireland           Donegal
# 3        gid://shopify/Order/4866325381233          Ireland            Dublin
# 4        gid://shopify/Order/4866326364273          Ireland            Offaly
# ...                                    ...              ...               ...
# 1145853   gid://shopify/Order/998004195441          Ireland           Wicklow
# 1145854   gid://shopify/Order/998103711857          Ireland            Dublin
# 1145855   gid://shopify/Order/998377652337          Ireland             Louth
# 1145856   gid://shopify/Order/998895288433          Ireland           Wexford
# 1145857   gid://shopify/Order/998967378033          Ireland            Offaly
#
# [1145858 rows x 3 columns]

# %%
order_line_items_df[["order_id","product_id"]]
# Out:
#                                   order_id  \
# 0        gid://shopify/Order/5699898048856
# 1        gid://shopify/Order/5699912434008
# 2        gid://shopify/Order/5699916923224
# 3        gid://shopify/Order/5700026794328
# 4        gid://shopify/Order/5700050157912
# ...                                    ...
# 2087825  gid://shopify/Order/3835520057457
# 2087826  gid://shopify/Order/3835597684849
# 2087827  gid://shopify/Order/3835755135089
# 2087828  gid://shopify/Order/3835826110577
# 2087829  gid://shopify/Order/3835826569329
#
#                                   product_id
# 0        gid://shopify/Product/4671125749873
# 1        gid://shopify/Product/6662534725745
# 2        gid://shopify/Product/4637992091761
# 3        gid://shopify/Product/4545826750577
# 4        gid://shopify/Product/6812022243441
# ...                                      ...
# 2087825  gid://shopify/Product/1856496533617
# 2087826  gid://shopify/Product/1608198979697
# ...

# %%
inventory_products_df[["inventory_id", "inventory_productType"]]
# Out:
#                               inventory_id inventory_productType
# 0      gid://shopify/Product/1607622000753           Dry Shampoo
# 1      gid://shopify/Product/1607622623345           Dry Shampoo
# 2      gid://shopify/Product/1607633862769        Tanning Mousse
# 3      gid://shopify/Product/1607636090993        Tanning Mousse
# 4      gid://shopify/Product/1607639138417              Face Oil
# ...                                    ...                   ...
# 3887  gid://shopify/Product/15432398143832              Gift Set
# 3888  gid://shopify/Product/15432415740248              Gift Set
# 3889  gid://shopify/Product/15432642036056       Skincare Bundle
# 3890  gid://shopify/Product/15432732016984       Skincare Bundle
# 3891  gid://shopify/Product/15432961491288       Skincare Bundle
#
# [3892 rows x 2 columns]

# %%
merged_df_2= merged_df.merge(inventory_products_df[["inventory_id", "inventory_productType"]], left_on="product_id", right_on="inventory_id", how="left")
merged_df_2.head()
# Out:
#   shipping_city shipping_country                           product_id  \
# 0      Kilkenny          Ireland  gid://shopify/Product/1608616280177
# 1   Ballisodare          Ireland  gid://shopify/Product/4637992091761
# 2  Kilmacrennan          Ireland  gid://shopify/Product/6839748558961
# 3        Dublin          Ireland  gid://shopify/Product/1608616280177
# 4  Tullamore,            Ireland  gid://shopify/Product/1608486223985
#
#                           inventory_id   inventory_productType
# 0  gid://shopify/Product/1608616280177  Vitamins & Supplements
# 1  gid://shopify/Product/4637992091761  Vitamins & Supplements
# 2  gid://shopify/Product/6839748558961  Vitamins & Supplements
# 3  gid://shopify/Product/1608616280177  Vitamins & Supplements
# 4  gid://shopify/Product/1608486223985  Vitamins & Supplements

# %%
merged_df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2087830 entries, 0 to 2087829
# Data columns (total 5 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   shipping_city          object
#  1   shipping_country       object
#  2   product_id             object
#  3   inventory_id           object
#  4   inventory_productType  object
# dtypes: object(5)
# memory usage: 79.6+ MB

# %% [markdown]
# ### clean features

# %%
orders = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\orders.csv")


order_line_items_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\order_line_items.csv")

inventory_products_df = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\inventory_products.csv")

merged_df = orders[["order_id","shipping_city","shipping_country"]].merge(order_line_items_df[["order_id","product_id"]], on="order_id", how="left").drop(columns = ["order_id"])
merged_df.head()

merged_df_2= merged_df.merge(inventory_products_df[["inventory_id", "inventory_productType"]], left_on="product_id", right_on="inventory_id", how="left")[["inventory_productType","shipping_country","shipping_city"]]
merged_df_2.head()
# Out:
# C:\Users\titou\AppData\Local\Temp\ipykernel_3480\3383451023.py:1: DtypeWarning: Columns (35,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   orders = pd.read_csv(r"C:\Users\titou\Desktop\paris_hack\input_data\Online\orders.csv")
#   shipping_city shipping_country                           product_id  \
# 0      Kilkenny          Ireland  gid://shopify/Product/1608616280177
# 1   Ballisodare          Ireland  gid://shopify/Product/4637992091761
# 2  Kilmacrennan          Ireland  gid://shopify/Product/6839748558961
# 3        Dublin          Ireland  gid://shopify/Product/1608616280177
# 4  Tullamore,            Ireland  gid://shopify/Product/1608486223985
#
#                           inventory_id   inventory_productType
# 0  gid://shopify/Product/1608616280177  Vitamins & Supplements
# 1  gid://shopify/Product/4637992091761  Vitamins & Supplements
# 2  gid://shopify/Product/6839748558961  Vitamins & Supplements
# ...

# %%
merged_df_2 = merged_df_2[["inventory_productType","shipping_country","shipping_city"]]
merged_df_2
# Out:
#           inventory_productType shipping_country          shipping_city
# 0        Vitamins & Supplements          Ireland               Kilkenny
# 1        Vitamins & Supplements          Ireland            Ballisodare
# 2        Vitamins & Supplements          Ireland           Kilmacrennan
# 3        Vitamins & Supplements          Ireland                 Dublin
# 4        Vitamins & Supplements          Ireland           Tullamore,
# ...                         ...              ...                    ...
# 2087825                Cleanser          Ireland                   Bray
# 2087826  Vitamins & Supplements          Ireland                 Dublin
# 2087827                  Lotion          Ireland                Dundalk
# 2087828                     NaN          Ireland  New Ross, Co. Wexford
# 2087829  Vitamins & Supplements          Ireland                  clara
#
# [2087830 rows x 3 columns]

# %% [markdown]
# # Clean function

# %%
import pandas as pd

def format_online_data_full(path_orders, path_order_line_items, path_inventory_products):

    orders = pd.read_csv(path_orders)
    order_line_items_df = pd.read_csv(path_order_line_items)
    inventory_products_df = pd.read_csv(path_inventory_products)

    merged_df = (
        orders[["order_id", "shipping_city", "shipping_country"]]
        .merge(order_line_items_df[["order_id", "product_id"]],
               on="order_id", how="left")
        .drop(columns=["order_id"])
    )

    merged_df_2 = (
        merged_df
        .merge(
            inventory_products_df[["inventory_id", "inventory_productType"]],
            left_on="product_id", right_on="inventory_id", how="left"
        )[["inventory_productType", "shipping_country", "shipping_city"]]
    )

    # Counts per product type
    counts = (
        merged_df_2
        .groupby(["shipping_country", "shipping_city", "inventory_productType"])
        .size()
        .reset_index(name="n_sold")
    )

    # Top-3 per location
    top3 = (
        counts
        .sort_values(["shipping_country", "shipping_city", "n_sold"],
                     ascending=[True, True, False])
        .groupby(["shipping_country", "shipping_city"])
        .head(3)
    )

    top3["rank"] = (
        top3
        .groupby(["shipping_country", "shipping_city"])["n_sold"]
        .rank(method="first", ascending=False)
        .astype(int)
    )

    # Pivot to wide format
    wide = (
        top3
        .pivot(index=["shipping_country", "shipping_city"],
               columns="rank",
               values="inventory_productType")
        .reset_index()
        .rename(columns={
            1: "top1_productType",
            2: "top2_productType",
            3: "top3_productType"
        })
    )

    # Total sold per location
    totals = (
        counts
        .groupby(["shipping_country", "shipping_city"])["n_sold"]
        .sum()
        .reset_index(name="total_n_sold")
    )

    # Merge totals + top3
    full_df = (
        totals
        .merge(wide, on=["shipping_country", "shipping_city"], how="left")
        .sort_values("total_n_sold", ascending=False)
        .reset_index(drop=True)
    )

    return full_df


def format_online_data_top20(full_df):
    return full_df.head(20)

# ####Example usecase:

# path_orders = r"C:\Users\titou\Desktop\paris_hack\input_data\Online\orders.csv"
# path_order_line_items= r"C:\Users\titou\Desktop\paris_hack\input_data\Online\order_line_items.csv"
# path_inventory_products = r"C:\Users\titou\Desktop\paris_hack\input_data\Online\inventory_products.csv"

# full = format_online_data_full(path_orders, path_order_line_items, path_inventory_products)
# top20 = format_online_data_top20(full)
