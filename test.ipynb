# %% [markdown]
# Sales:
#
# Product,Packsize,Headoffice ID,Barcode,OrderList,Branch Name,Dept Fullname,Group Fullname,Trade Price,
# RRP,Sale Date,Sale ID,Qty Sold,Turnover,Vat Amount,Sale VAT Rate,Turnover ex VAT,Disc Amount,Discount Band,
# Profit,Refund Qty,Refund Value
#
# Inventory:
#
# Product,Packsize,Headoffice ID,Barcode,Barcode2,Barcode3,OrderList,Case Size,Trade Price,RRP,Dept Fullname,
# Group Fullname,Branch Name,Branch Stock Level

# %% [markdown]
# Product,Packsize,Headoffice ID,Barcode,OrderList,Branch Name,Dept Fullname,Group Fullname,Trade Price,RRP,Sale Date,Sale ID,Qty Sold,Turnover,Vat Amount,Sale VAT Rate,Turnover ex VAT,Disc Amount,Discount Band,Profit,Refund Qty,Refund Value
# Revive Active Tropical Health Food Supplement 30s  ,30,93754,794712847861,Galway Natural Health Company,Baggot St,Vitamins,Revive Active,26.59,59.95,2023-09-01 08:05:00,6219657,1,44.96,5.35,13.5,39.61,14.99,None,8.69,0,0.0
# Catrice True Skin High Cover Concealer 010,0,90866,4059729277084,SCL Catrice Make Up,Baggot St,Self Selection Stands,Catrice Make Up,2.53,4.65,2023-09-01 08:13:00,6219658,1,4.95,0.93,23.0,4.02,0.0,None,1.32,0,0.0
# Durex Thin Feel 6s,6's,47131,5052197025989,Reckitt Benckiser Group,Baggot St,OTC : Family Planning,Family Planning,4.2,8.5,2023-09-01 08:25:00,6219659,1,6.0,0.71,13.5,5.29,0.0,None,2.33,0,0.0
